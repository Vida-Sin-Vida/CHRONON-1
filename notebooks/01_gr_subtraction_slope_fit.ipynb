# %% [markdown]
# # 01 GR Subtraction & Slope Fit
#
# This notebook implements the primary detection analysis:
# 1. Load processed data
# 2. Perform WLS fit of $Y_{res}$ vs $X_{GR}$
# 3. Check Andrews HAC errors
# 4. Produce residual plots

# %%
import pandas as pd
import numpy as np
from chronon_core import stats, io

# Load data
# df = pd.read_csv('data/processed/run_X.csv')
# stats.fit_free_intercept_wls(...)
